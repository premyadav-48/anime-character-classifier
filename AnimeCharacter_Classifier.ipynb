# %% [markdown]
# # 1.1 Install Dependencies

# %%
#pip install tensorflow_hub

# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# # 1.2 os in action

# %%
data_dir = 'data'

# %%
#os.listdir(data_dir)

# %%
img = cv2.imread(os.path.join('data','albedo','__albedo_overlord_drawn_by_rhineheim__sample-b0a3d00c746e404a46fdfc18cb0d54d7.jpg'))

# %%
plt.imshow(img)

# %%
img.resize
# Out:
# <function ndarray.resize>

# %%
img.shape
# Out:
# (96, 96, 3)

# %% [markdown]
# ## Make predictions using a ready-made model: MobileNetV2 (without any training)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 9
#       7 # Instantiate layer first
#       8 mobilenet = hub.KerasLayer(model_url, input_shape=IMAGE_SHAPE + (3,))
# ----> 9 outputs = mobilenet(inputs)  # NOW it's valid
#      11 # Define model
#      12 model = tf.keras.Model(inputs=inputs, outputs=outputs)
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\tensorflow_hub\keras_layer.py:250, in KerasLayer.call(self, inputs, training)
#     247   else:
#     248     # Behave like BatchNormalization. (Dropout is different, b/181839368.)
#     249     training = False
# --> 250   result = smart_cond.smart_cond(training,
#     251                                  lambda: f(training=True),
#     252                                  lambda: f(training=False))
#     254 # Unwrap dicts returned by signatures.
#     255 if self._output_key:
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\tensorflow_hub\keras_layer.py:252, in KerasLayer.call.<locals>.<lambda>()
#     247   else:
#     248     # Behave like BatchNormalization. (Dropout is different, b/181839368.)
#     249     training = False
#     250   result = smart_cond.smart_cond(training,
#     251                                  lambda: f(training=True),
# --> 252                                  lambda: f(training=False))
#     254 # Unwrap dicts returned by signatures.
#     255 if self._output_key:
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\tensorflow\core\function\polymorphism\function_type.py:587, in canonicalize_to_monomorphic(args, kwargs, default_values, capture_types, polymorphic_type)
#     581       parameters.append(
#     582           _make_validated_mono_param(kwarg_name, arg[kwarg_name],
#     583                                      Parameter.KEYWORD_ONLY, type_context,
#     584                                      poly_parameter.type_constraint))
#     585   else:
#     586     parameters.append(
# --> 587         _make_validated_mono_param(name, arg, poly_parameter.kind,
#     588                                    type_context,
#     589                                    poly_parameter.type_constraint))
#     591 return FunctionType(parameters, capture_types), type_context
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\tensorflow\core\function\polymorphism\function_type.py:526, in _make_validated_mono_param(name, value, kind, type_context, poly_type)
#     522 def _make_validated_mono_param(
#     523     name, value, kind, type_context, poly_type
#     524 ) -> Parameter:
#     525   """Generates and validates a parameter for Monomorphic FunctionType."""
# --> 526   mono_type = trace_type.from_value(value, type_context)
#     528   if poly_type and not mono_type.is_subtype_of(poly_type):
#     529     raise TypeError(f"Parameter `{name}` was expected to be of type "
#     530                     f"{poly_type} but is {mono_type}")
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\tensorflow\core\function\trace_type\trace_type_builder.py:185, in from_value(value, context)
#     178   return default_types.Attrs.from_type_and_attributes(
#     179       type(value),
#     180       tuple(
#     181           from_value(getattr(value, a.name), context)
#     182           for a in value.__attrs_attrs__))
#     184 if util.is_np_ndarray(value):
# --> 185   ndarray = value.__array__()
#     186   return default_types.TENSOR(ndarray.shape, ndarray.dtype)
#     188 if isinstance(value, custom_nest_protocol.CustomNestProtocol):
#
# File D:\ML\Deep Learning\sad-happy-classifier\tf-env\Lib\site-packages\keras\src\backend\common\keras_tensor.py:126, in KerasTensor.__array__(self)
#     125 def __array__(self):
# --> 126     raise ValueError(
#     127         "A KerasTensor is symbolic: it's a placeholder for a shape "
#     128         "an a dtype. It doesn't have any actual numerical value. "
#     129         "You cannot convert it to a NumPy array."
#     130     )
#
# ValueError: Exception encountered when calling layer 'keras_layer_3' (type KerasLayer).
#
# A KerasTensor is symbolic: it's a placeholder for a shape an a dtype. It doesn't have any actual numerical value. You cannot convert it to a NumPy array.
#
# Call arguments received by layer 'keras_layer_3' (type KerasLayer):
#   • inputs=<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_1>
#   • training=None
